# %%
from sklearn                        import metrics, svm
from sklearn.linear_model           import LogisticRegression
from sklearn import preprocessing
from sklearn import utils

# %%
import numpy as np
import math

def getData():
  inputs = list()
  outputs = list()
  for x in range(-10, 10):
    for y in range(50):
      for z in range(10, 50):
        inputs.append([x / 10, y / 10, z / 10])
        outputs.append([math.pow(x / 10, 2) + 2 * (x / 10) * (y / 10) - math.sqrt(z / 10)])
  return (np.array(inputs), np.array(outputs))

X, y = getData()
print(X.shape)
print(y.shape)
# Out:
# (40000, 3)
# (40000, 1)

# %%
clf = svm.SVR(gamma='scale', kernel='rbf')
clf.fit(X, y)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='scale',
#     kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

# %%
import random
for itr in range(10):
  x = random.randint(0,100) / 100 * 2 - 1
  y = random.randint(0,100) / 100 * 5
  z = random.randint(0,100) / 100 * 4 + 1
  pred = clf.predict([[x, y, z]])
  res = (x * x + 2 * x * y - math.sqrt(z))
  er = abs(pred[0] - res)
  print("Arguments: x = %.2f, y = %.2f, z = %.2f, net predict = %f, actual result = %f, error = %f" % (x, y, z, pred[0], res, er))
# Out:
# Arguments: x = 0.48, y = 4.15, z = 3.32, net predict = 2.478539, actual result = 2.392313, error = 0.086226
# Arguments: x = -0.48, y = 2.65, z = 4.40, net predict = -4.448144, actual result = -4.411218, error = 0.036926
# Arguments: x = -0.68, y = 4.70, z = 1.36, net predict = -7.123944, actual result = -7.095790, error = 0.028154
# Arguments: x = 0.82, y = 4.30, z = 1.32, net predict = 6.526919, actual result = 6.575487, error = 0.048568
# Arguments: x = -0.32, y = 1.25, z = 3.12, net predict = -2.473008, actual result = -2.463952, error = 0.009056
# Arguments: x = -0.74, y = 3.30, z = 2.76, net predict = -5.983209, actual result = -5.997725, error = 0.014516
# Arguments: x = 0.10, y = 4.75, z = 2.64, net predict = -0.624832, actual result = -0.664808, error = 0.039976
# Arguments: x = -0.66, y = 0.65, z = 3.40, net predict = -2.217644, actual result = -2.266309, error = 0.048665
# Arguments: x = 0.34, y = 1.25, z = 4.04, net predict = -0.986661, actual result = -1.044375, error = 0.057714
# Arguments: x = 0.52, y = 0.35, z = 4.28, net predict = -1.416576, actual result = -1.434416, error = 0.017841
